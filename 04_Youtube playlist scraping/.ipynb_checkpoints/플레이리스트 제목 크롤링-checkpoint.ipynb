# %%
# 0. 라이브러리 불러오기
from bs4 import BeautifulSoup as bs
import urllib.request
import pandas as pd

# %%
playlist_url = ['https://www.youtube.com/playlist?list=PLPKZ6FAxaaf_mlK960KUVNp6GGW3TCfQe', 
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf9mBJBR9GfQrn-vhYtU1hMf',
               'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-CypAyYlCEhwC021-L7RG6',
               'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf84tyUkdnx3c5JxZ00-rGSu',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf9ol1GU68Z1F3BmXOMM2yYg',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf_M6QbHniDuOH72dWi0-yIm',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf_-QcMvllxn6VD4xY-hRkj3',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf8UAmP0b9jDquvTcbNUopwe',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf9ve5PmOfLul2YmKqFy1BiW',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-PFri6jI4T6gc-eFoM6vuS',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf_-0fbjwrvsGIXdHtkkRx7-',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf_7OD2RK8hUGSCCJd91uFQ6',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf8lr7Cs_ebaZ7BAZomtAAte',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-9VWC5yUVo3XKBXujNS9Fp',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf8Qy0qwF2l_z0hDY2eMkBDj',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-1DlgYO-jNoGrOWs5hxtnF',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf9kH9m52BZ_iyy1n6ll-fwU',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf_d8w2hLcfu6ath9nh6T6MF',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf9Kx9UXB4kbQHjqaO5-3qEP',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf9OCNJ78XPZ2um0UBeVwszD',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-3hB25RxNtE6AE7ZtaU5Qp',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf_xuAQPdNiL8vpNXmlbPpDt',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf9HzZluME97m3YR8VW8eecu',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf8ZgzLvW8WWpAHxS4unCEwv',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-_lMPVx_8lqjrbzoQz1bs-',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf9Rshcledolpp2btBCZPPTz',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf_BHrvuSeEdHAlz9iIqXex3',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-rwhaSfuENK0jtxSLDY0gv',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf_yPICacEriKUZNGCVnejsb',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-fn_89jK5gKjTeEnrgcPNZ',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf8SvwHeoLOrDyxEerJFwSu8',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf_PHNrkCrQY44IDrInhZMbu',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-HBMxB0udxPNS4fbgIGJ7U',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-FG89RDpcj93J5_kCy6VIk',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf90RHGzpRbyZT27AIvAuUy3',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf_pQhrkVk4ZF5W-PAHDF5XX',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-QGIbdZkW8j-b7liNj-X34'
               ]
print(len(set(playlist_url)))
# Out:
# 37

# %%
playlist_url[36]
# Out:
# 'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-QGIbdZkW8j-b7liNj-X34'

# %%
from bs4 import BeautifulSoup as bs
import urllib.request

cannot_crawl = []

for i in range(37):
    html = urllib.request.urlopen(playlist_url[i])
    response = html.read()
    soup = bs(response)
    # print(soup)
    res = soup.select_one('title').text()
    print(res)
    res2 = soup.find_all('a', {'class':'pl-video-title-link'})
    title_list=[]
    for t in res2:
        title = t.get_text().replace('\n', '').strip()
        title_list.append(title)
        
    if len(title_list)== 0:
        print(url)
        cannot_crawl.append(url)
        

    else:
        df = pd.DataFrame(data=title_list, columns=['곡 제목'])
        df = df.applymap(lambda x: x.replace('\u2013','').replace('\u2013',''))
        df = df.applymap(lambda x: x.replace('\u982c','').replace('\u982c','')) 
        df = df.applymap(lambda x: x.replace('\u30fc','').replace('\u30fc',''))
        df = df.applymap(lambda x: x.replace('\u2014','').replace('\u2014',''))

        df.to_csv('playlist'+str(i)+'.csv', encoding='cp949')
        print(title_list)
# Out:
# ['Fitz And The Tantrums vs Song Hae - 전국 Handclap 자랑 (feat. Casino) (J.E.B Edit)', 'BTS (방탄소년단) - MIC Drop Lyrics [Color Coded_Han_Rom_Eng]', 'MAX - Acid Dreams (Official Audio)', "[DICKPUNKS] 딕펑스 'VIVA청춘' official MV", '[Official Audio] Just Get Away(괜찮아 떠나) - Sweet Sorrow(스윗소로우)', '이하이 (LEE HI)_ 한숨 BREATHE [LYRICS] 가사 한국어', 'Like a child (아이처럼)', '사랑에 빠지고 싶다', '보아(BoA)_ No.1 [LYRICS] 가사 한국어', '[空耳/韓文 Hangul가사] DinDin(딘딘) - Must be the money (金科長 김과장 OST)', "Kim Bo Kyung - Don't Think You're Alone", '노라조 - 니팔자야 가사']
# ['장미여관(Rosemotel) - 퇴근하겠습니다 MV', '크러쉬 (Crush) - 가끔 (Sometimes) 가사', "Rose Motel (장미여관) - 내 스타일 아냐 (That's Not My Style) [Digital Single - That's Not My Style]", "[응답하라 1988 Part 2] 이적 - 걱정말아요 그대 (Don't worry)", '너에게 난, 나에게 넌', '지금 이 순간 - 홍광호', '박상철 - 황진이.wmv', '박현빈 오빠만 믿어', '배기성 - 오늘도 참는다', '캔(Can)   가라가라 (가사 첨부)']
# ...

# %%
cannot_crawl
# Out:
# ['https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-QGIbdZkW8j-b7liNj-X34',
#  'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-QGIbdZkW8j-b7liNj-X34',
#  'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-QGIbdZkW8j-b7liNj-X34',
#  'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-QGIbdZkW8j-b7liNj-X34',
#  'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-QGIbdZkW8j-b7liNj-X34',
#  'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-QGIbdZkW8j-b7liNj-X34']

# %%
import random

example_list = random.choice(playlist_url)

for i in range(37):
    html = urllib.request.urlopen(playlist_url[i])
    response = html.read()
    soup = bs(response)
    # print(soup)
    res = soup.find('title').get_text()
    print(res.replace('- YouTube', ''))
    res2 = soup.find_all('a', {'class':'pl-video-title-link'})
    title_list=[]
    for t in res2:
        title = t.get_text().replace('\n', '').strip()
        title_list.append(title)


        df = pd.DataFrame(data=title_list, columns=['곡 제목'])
        df = df.applymap(lambda x: x.replace('\u2013','').replace('\u2013',''))
        df = df.applymap(lambda x: x.replace('\u982c','').replace('\u982c','')) 
        df = df.applymap(lambda x: x.replace('\u30fc','').replace('\u30fc',''))
        df = df.applymap(lambda x: x.replace('\u2014','').replace('\u2014',''))

        df.to_csv(res+'.csv', encoding='cp949')
        print(title_list)
# Out:
# 혼밥
# ['Fitz And The Tantrums vs Song Hae - 전국 Handclap 자랑 (feat. Casino) (J.E.B Edit)']
# ['Fitz And The Tantrums vs Song Hae - 전국 Handclap 자랑 (feat. Casino) (J.E.B Edit)', 'BTS (방탄소년단) - MIC Drop Lyrics [Color Coded_Han_Rom_Eng]']
# ['Fitz And The Tantrums vs Song Hae - 전국 Handclap 자랑 (feat. Casino) (J.E.B Edit)', 'BTS (방탄소년단) - MIC Drop Lyrics [Color Coded_Han_Rom_Eng]', 'MAX - Acid Dreams (Official Audio)']
# ['Fitz And The Tantrums vs Song Hae - 전국 Handclap 자랑 (feat. Casino) (J.E.B Edit)', 'BTS (방탄소년단) - MIC Drop Lyrics [Color Coded_Han_Rom_Eng]', 'MAX - Acid Dreams (Official Audio)', "[DICKPUNKS] 딕펑스 'VIVA청춘' official MV"]
# ['Fitz And The Tantrums vs Song Hae - 전국 Handclap 자랑 (feat. Casino) (J.E.B Edit)', 'BTS (방탄소년단) - MIC Drop Lyrics [Color Coded_Han_Rom_Eng]', 'MAX - Acid Dreams (Official Audio)', "[DICKPUNKS] 딕펑스 'VIVA청춘' official MV", '[Official Audio] Just Get Away(괜찮아 떠나) - Sweet Sorrow(스윗소로우)']
# ...

# %%
left_playlist = ['https://www.youtube.com/playlist?list=PLPKZ6FAxaaf_BHrvuSeEdHAlz9iIqXex3',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf9ol1GU68Z1F3BmXOMM2yYg',
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf8SvwHeoLOrDyxEerJFwSu8'
                'https://www.youtube.com/playlist?list=PLPKZ6FAxaaf-PFri6jI4T6gc-eFoM6vuS']


for playlist in left_playlist:
    html = urllib.request.urlopen(playlist)
    response = html.read()
    soup = bs(response)
    # print(soup)
    res = soup.find('title').get_text()
    print(res.replace('- YouTube', ''))
    res2 = soup.find_all('a', {'class':'pl-video-title-link'})
    title_list=[]
    for t in res2:
        title = t.get_text().replace('\n', '').strip()
        title_list.append(title)


        df = pd.DataFrame(data=title_list, columns=['곡 제목'])
        df = df.applymap(lambda x: x.replace('\u2013','').replace('\u2013',''))
        df = df.applymap(lambda x: x.replace('\u982c','').replace('\u982c','')) 
        df = df.applymap(lambda x: x.replace('\u30fc','').replace('\u30fc',''))
        df = df.applymap(lambda x: x.replace('\u2014','').replace('\u2014',''))

        df.to_csv(res+'.csv', encoding='cp949')
        print(title_list)
# Out:
# ì¹œêµ¬
# 죄송합니다. 문제가 발생했습니다.
